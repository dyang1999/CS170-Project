# %%
# Install packages
# %pip install networkx
# %pip install numpy
# %pip install tqdm
# %pip install matplotlib
# Out:
# Requirement already satisfied: networkx in /opt/conda/lib/python3.9/site-packages (2.6.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (1.21.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.9/site-packages (4.62.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.9/site-packages (3.5.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (2.8.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# The starter code is short and simple, take a look!
from starter import *

# %% [markdown]
# # Phase 1 - Create Inputs

# %%
# Add edges with G.add_edge(u, v, weight=w)
# Idea: consider making the inputs with a solution in mind, 
# such that you know the solution when the outputs are released
import random

def sample(total, constraints):
    import numpy as np
    rng = np.random.default_rng()
    samples = rng.multinomial(total, [x / sum(constraints) for x in constraints], size=100)
    return next(val for val in samples if np.all(val < constraints))


def small(G: nx.Graph):
    # TODO add edges to complete the small input
    # each edge weight max 1000, max number of edges 10000, sum of edge weights at least 500000
    # number of nodes 100

    # Just generate N random numbers (number of edges), compute their sum, divide each one by the sum and multiply by M (MAX_WEIGHT)
    MAX_EDGES_SMALL = min((N_SMALL * (N_SMALL - 1)) // 2, MAX_EDGES)
    constraints = [1000] * MAX_EDGES_SMALL
    total = random.randint(500000, 1000*MAX_EDGES_SMALL)
    samples = sample(total, constraints)

    print(len(samples))

    for edge in samples:
        first_node = random.choice(list(G.nodes()))                  # pick a random node
        possible_nodes = set(list(G.nodes()))
        neighbours = list(G.neighbors(first_node)) + [first_node]
        possible_nodes.difference_update(neighbours)    # remove the first node and all its neighbours from the candidates
        if len(possible_nodes) == 0:
            continue
        second_node = random.choice(list(possible_nodes))      # pick second node      
        G.add_edge(first_node, second_node, weight=int(edge))
    
    pass
    
def medium(G: nx.Graph):
    # TODO add edges to complete the medium input
    MAX_EDGES_MEDIUM = min((N_MEDIUM * (N_MEDIUM - 1)) // 2, MAX_EDGES)
    constraints = [1000] * MAX_EDGES_MEDIUM
    total = random.randint(500000, 1000*MAX_EDGES_MEDIUM)
    samples = sample(total, constraints)

    print(len(samples))

    for edge in samples:
        first_node = random.choice(list(G.nodes()))                  # pick a random node
        possible_nodes = set(list(G.nodes()))
        neighbours = list(G.neighbors(first_node)) + [first_node]
        possible_nodes.difference_update(neighbours)    # remove the first node and all its neighbours from the candidates
        if len(possible_nodes) == 0:
            continue
        second_node = random.choice(list(possible_nodes))      # pick second node      
        G.add_edge(first_node, second_node, weight=int(edge))
    
    pass
    
def large(G: nx.Graph):
    # TODO add edges to complete the large input
    MAX_EDGES_LARGE = min((N_LARGE * (N_LARGE - 1)) // 2, MAX_EDGES)
    constraints = [1000] * MAX_EDGES_LARGE
    total = random.randint(500000, 1000*MAX_EDGES_LARGE)
    samples = sample(total, constraints)

    print(len(samples))

    for edge in samples:
        first_node = random.choice(list(G.nodes()))                  # pick a random node
        possible_nodes = set(list(G.nodes()))
        neighbours = list(G.neighbors(first_node)) + [first_node]
        possible_nodes.difference_update(neighbours)    # remove the first node and all its neighbours from the candidates
        if len(possible_nodes) == 0:
            continue
        second_node = random.choice(list(possible_nodes))      # pick second node      
        G.add_edge(first_node, second_node, weight=int(edge))
    
    pass

# %%
G = nx.empty_graph(N_SMALL)
small(G)
write_input(G, 'small.in', True)

G = nx.empty_graph(N_MEDIUM)
medium(G)
write_input(G, 'medium.in', True)

G = nx.empty_graph(N_LARGE)
large(G)
write_input(G, 'large.in', True)

# %% [markdown]
# # Phase 2 - Implement your Solver

# %%
from random import choice
from collections import defaultdict

def solve5(G: nx.Graph, no_teams):
    # TODO implement this function with your solver
    # Assign a team to v with G.nodes[v]['team'] = team_id
    # Access the team of v with team_id = G.nodes[v]['team']
    
    all_nodes = list(G.nodes)
    teams = defaultdict(list)
    for team_id in range(1, 1 + no_teams):
        indegree = [0, float('inf')]
        for n in all_nodes:
            if G.degree(n) < indegree[1]:
                indegree = [n, G.degree(n)]
        start_node = indegree[0]
        all_nodes.remove(start_node)
        G.nodes[start_node]['team'] = team_id
        teams[team_id].append(start_node)
        
    team_size = G.number_of_nodes() // no_teams    
    
    count = 0
    while all_nodes:
        team_to_add = (count % no_teams) + 1
        add_node5(teams, team_to_add, all_nodes, G)
        count += 1
    
    minScore = score(G)
    oldScore = float('inf')
    all_nodes = list(G.nodes)
    while oldScore > minScore:
        oldScore = minScore
        minScore = score(G)
        cw, ck, cp = score(G, separated=True)
        for node in all_nodes:
            for i in range(1, no_teams+1):
                currentScore = ck + update_Cw_score(G, cw, node, G.nodes[node]['team'], i) + update_Cp_score(G, teams, cp, node, G.nodes[node]['team'], i)
                if currentScore < minScore: 
#                     def update_Cw_score(G: nx.Graph, previousScore: float, penguin: int, i: int, j: int):
#                     def update_Cp_score(G: nx.Graph, teams, previousScore: float, penguin: int, i: int, j:int):
                    minScore = currentScore
                    cw = update_Cw_score(G, cw, node, G.nodes[node]['team'], i)
                    cp = update_Cp_score(G, teams, cp, node, G.nodes[node]['team'], i)
                    old_team = G.nodes[node]['team']
                    teams[old_team].remove(node)
                    teams[i].append(node)
                    G.nodes[node]['team'] = i
    
def add_node5(teams, team_id, all_nodes, G):
    team_nodes = teams[team_id]
    possible_nodes = set(all_nodes.copy())
    neighbours = set()
    # Accumulate all neighbours 
    for node in team_nodes:
        for avail_node in all_nodes:
            if G.has_edge(avail_node, node):
                neighbours.add(avail_node)
    possible_nodes.difference_update(neighbours) 
    non_neighbours = list(possible_nodes)
                          
    # First choose among non-neighbours
    if non_neighbours:
        # Select random non-neighbour who doesn't have a team_id yet
        # Choose non-neighbour with the smallest indegree first
        indegree = [0, float('inf')]
        for n in non_neighbours:
            if G.degree(n) < indegree[1]:
                indegree = [n, G.degree(n)]
        target_node = indegree[0]
        all_nodes.remove(target_node)
        teams[team_id].append(target_node)
        G.nodes[target_node]['team'] = team_id
    else:
        # If no non-neighbours, choose neighbouring node with min edge weight
        min_node = [0, float('inf')]

        for n in neighbours:
            sum_weights = 0
            for n1 in teams[team_id]:
                if G.has_edge(n, n1):
                    sum_weights += G[n][n1]['weight']
            if sum_weights < min_node[1]:
                min_node = [n, sum_weights]
        teams[team_id].append(min_node[0])
        all_nodes.remove(min_node[0])
        G.nodes[min_node[0]]['team'] = team_id

# %%
from random import choice
from collections import defaultdict

def solve6(G: nx.Graph):
    # TODO implement this function with your solver
    # Assign a team to v with G.nodes[v]['team'] = team_id
    # Access the team of v with team_id = G.nodes[v]['team']
    cost = float('inf')
    no_teams = 2
    flag = True 
    while flag:
        no_teams += 1
        all_nodes = list(G.nodes)
        teams = defaultdict(list)
        for team_id in range(1, 1 + no_teams):
            indegree = [0, float('inf')]
            for n in all_nodes:
                if G.degree(n) < indegree[1]:
                    indegree = [n, G.degree(n)]
            start_node = indegree[0]
            all_nodes.remove(start_node)
            G.nodes[start_node]['team'] = team_id
            teams[team_id].append(start_node)

        team_size = G.number_of_nodes() // no_teams
        count = 0
        while all_nodes:
            team_to_add = (count % no_teams) + 1
            add_node6(teams, team_to_add, all_nodes, G)
            count += 1
            
        result = score(G)
        if result < cost:
            G_result = G.copy()
            cost = result
#             print(no_teams, result, cost)
        else:
            flag = False
    
    optTeams = no_teams - 1
    solve5(G, optTeams)
    
def add_node6(teams, team_id, all_nodes, G):
    team_nodes = teams[team_id]
    possible_nodes = set(all_nodes.copy())
    neighbours = set()
    # Accumulate all neighbours 
    for node in team_nodes:
        for avail_node in all_nodes:
            if G.has_edge(avail_node, node):
                neighbours.add(avail_node)
    possible_nodes.difference_update(neighbours) 
    non_neighbours = list(possible_nodes)
                          
    # First choose among non-neighbours
    if non_neighbours:
        # Select random non-neighbour who doesn't have a team_id yet
        # Choose non-neighbour with the smallest indegree first
        indegree = [0, float('inf')]
        for n in non_neighbours:
            if G.degree(n) < indegree[1]:
                indegree = [n, G.degree(n)]
        target_node = indegree[0]
        all_nodes.remove(target_node)
        teams[team_id].append(target_node)
        G.nodes[target_node]['team'] = team_id
        
    else:
        # If no non-neighbours, choose neighbouring node with min edge weight
        min_node = [0, float('inf')]

        for n in neighbours:
            sum_weights = 0
            for n1 in teams[team_id]:
                if G.has_edge(n, n1):
                    sum_weights += G[n][n1]['weight']
            if sum_weights < min_node[1]:
                min_node = [n, sum_weights]
        teams[team_id].append(min_node[0])
        all_nodes.remove(min_node[0])
        G.nodes[min_node[0]]['team'] = team_id

# %%
def update_Cw_score(G: nx.Graph, previousScore: float, penguin: int, i: int, j: int):
    
    # get all neighbours and see which are from the same team
    
    # go through all neighbours, and get total weights of all edges from team i and all edges from team j
    team_i_weight = 0
    team_j_weight = 0
    for neighbour in G[penguin]:
        if G.nodes[neighbour]['team'] == i:
            team_i_weight += G[penguin][neighbour]['weight']
        if G.nodes[neighbour]['team'] == j:
            team_j_weight += G[penguin][neighbour]['weight']
    
    return previousScore - team_i_weight + team_j_weight

def update_Cp_score(G: nx.Graph, teams, previousScore: float, penguin: int, i: int, j:int):
    # find b 
    b = np.log(previousScore) / 70
    
    # find number of people in team i
    p_i = len(teams[i])
    p_j = len(teams[j])
    
    n = G.number_of_nodes()
    k = len(teams.keys())
    
    b_i = (p_i / n) - (1 / k)
    b_j = (p_j / n) - (1 / k)
    
    new_b = ( (b ** 2) - (b_i ** 2) - (b_j ** 2) + ((b_i - (1/n)) ** 2) + ((b_j + (1/n)) ** 2) ) ** 0.5
    
    return math.exp(70 * new_b)

# %%
G = read_input('inputs/large258.in')
solve6(G)
validate_output(G)
visualize(G)
# nx.draw(G)
score(G)
# Out:
# 5579.351038754716

# %%
run_all(solve6, 'inputs', 'output')
tar('output')
# Out:
#   0%|          | 0/780 [00:00<?, ?it/s]
# inputs/large225.in: cost 2009.6378778446226
# inputs/small232.in: cost 8576.115776315984
# inputs/large116.in: cost 15051.026254565539
# inputs/large59.in: cost 32019.223411754858
# inputs/small150.in: cost 91885.49323151434
# inputs/large147.in: cost 170040696.61889112
# inputs/small101.in: cost 138185.49323151432
# inputs/small197.in: cost 104170.01581064695
# inputs/small206.in: cost 8885.373407952706
# inputs/large240.in: cost 3.9604009070694736e+19
# inputs/medium7.in: cost 135786.97081429444
# inputs/small257.in: cost 241320.01581064696
# inputs/large180.in: cost 14842.639040069997
# inputs/large211.in: cost 56737.156720410574
# inputs/small135.in: cost 140213.43036750826
# inputs/small68.in: cost 32021.228627836368
# inputs/medium249.in: cost 2009.5536923187667
# inputs/large173.in: cost 7336.114420723395
# inputs/small164.in: cost 16953.870601390787
# inputs/medium218.in: cost 5503.218313968969
# inputs/medium189.in: cost 9152.302652966944
# inputs/small39.in: cost 6613.448304525242
# inputs/large122.in: cost 1219.3534567936856
# inputs/medium84.in: cost 5461.205948025516
# inputs/medium26.in: cost 100104.04582634693
# inputs/medium77.in: cost 226522312.79285693
# inputs/medium43.in: cost 2507.0547484350577
# inputs/medium12.in: cost 80456.58213114773
# inputs/medium53.in: cost 740.5002796512933
# inputs/medium67.in: cost 122859.12341746793
# inputs/medium36.in: cost 2.4958452573439736e+16
# inputs/medium94.in: cost 33470.80470941328
# inputs/large132.in: cost 4654487967114299.0
# inputs/small174.in: cost 99846.49323151434
# inputs/small29.in: cost 162809.01581064696
# inputs/medium199.in: cost 27757.165001366444
# inputs/medium208.in: cost 5680.749730503738
# inputs/large163.in: cost 8.80128656781108e+21
# inputs/small125.in: cost 59994.002241298585
# inputs/medium259.in: cost 46489.4533531445
# inputs/small78.in: cost 224346.01581064696
# inputs/large201.in: cost 9003.110925528175
# inputs/large190.in: cost 25392.09925710472
# inputs/small247.in: cost 15431264810909.729
# inputs/large250.in: cost 18858.628949909762
# inputs/small216.in: cost 32842.31591025766
# inputs/small187.in: cost 151276.49323151432
# inputs/small111.in: cost 169092.01581064696
# inputs/large157.in: cost 25520.3609956413
# inputs/large18.in: cost 49097.72515617163
# inputs/small140.in: cost 4091444.1412500436
# inputs/large49.in: cost 20942.343738412135
# inputs/large106.in: cost 2009.7624110467814
# inputs/small222.in: cost 402517.3688118974
# inputs/large235.in: cost 16903.988372020412
# inputs/small253.in: cost 97973.90918776828
# inputs/medium3.in: cost 344515.6535340232
# inputs/large215.in: cost 20147.30138316846
# inputs/large184.in: cost 1219.2493960703473
# inputs/small202.in: cost 273413.01581064693
# inputs/small193.in: cost 8969.634815562189
# inputs/large244.in: cost 5461.519217501946
# inputs/small160.in: cost 26493.746671151974
# inputs/large126.in: cost 1339.4683461511656
# inputs/large69.in: cost 449.2277266951576
# inputs/small131.in: cost 35565.31063892267
# inputs/large38.in: cost 413544.2916847747
# inputs/large177.in: cost 10527.830772977019
# inputs/small236.in: cost 8388.2044869442
# inputs/large221.in: cost 14843.112089954102
# inputs/large143.in: cost 2009.7921335687965
# inputs/small58.in: cost 6193.853839147427
# inputs/small105.in: cost 378517.3688118974
# inputs/large112.in: cost 16109.1270741919
# inputs/medium228.in: cost 21444.992492811816
# inputs/small154.in: cost 26477.273025618368
# inputs/medium16.in: cost 15804734.0485046
# inputs/medium47.in: cost 35471.451026151764
# inputs/medium80.in: cost 56778.77770728635
# inputs/medium73.in: cost 81134.46887218827
# inputs/medium22.in: cost 3697.1519579040087
# inputs/medium32.in: cost 5649430669719934.0
# inputs/medium63.in: cost 6453.506101865805
# inputs/medium90.in: cost 14842.31591025766
# inputs/medium57.in: cost 6195.021544850905
# inputs/small19.in: cost 266451.01581064693
# inputs/medium238.in: cost 3314.2997225117306
# inputs/small144.in: cost 259521.01581064696
# inputs/large102.in: cost 32895.23736542422
# inputs/small48.in: cost 140614.49323151432
# inputs/small115.in: cost 27853.564972592034
# inputs/large153.in: cost 5461.002045057636
# inputs/large231.in: cost 14844.759266065092
# inputs/small226.in: cost 3322.204486944198
# inputs/large260.in: cost 25924.055532457198
# inputs/large167.in: cost 25585.379807450903
# inputs/large28.in: cost 5461.114420723395
# inputs/small121.in: cost 15047.96893421961
# inputs/large79.in: cost 3.111948248571127e+22
# inputs/large136.in: cost 1219.4364378135592
# inputs/small170.in: cost 63521.48951581028
# inputs/large254.in: cost 15749.724978357786
# inputs/small183.in: cost 744.4603010261907
# inputs/small212.in: cost 276520.01581064693
# inputs/large194.in: cost 3312.712004651994
# inputs/large205.in: cost 16550.313795437105
# inputs/small243.in: cost 368498.85251697164
# inputs/medium2.in: cost 162892.2914781698
# inputs/small252.in: cost 122080.48951581027
# inputs/large185.in: cost 25969288324.329185
# inputs/large214.in: cost 41522.75452498404
# inputs/small192.in: cost 37158.31591025766
# inputs/small203.in: cost 402517.3688118974
# inputs/large245.in: cost 9448.663475185365
# inputs/small161.in: cost 584823.2213437884
# inputs/large68.in: cost 3312.9426666402182
# inputs/large127.in: cost 2009.729150573242
# inputs/small130.in: cost 136425.93063719754
# inputs/large176.in: cost 5461.002045057636
# inputs/large39.in: cost 1219.3996698692044
# inputs/small237.in: cost 122342.97388281235
# inputs/large220.in: cost 17115.833654646944
# inputs/large142.in: cost 4694436509.352166
# inputs/small104.in: cost 62548.90234638537
# inputs/small59.in: cost 402517.3688118974
# inputs/large113.in: cost 2017.5142890410157
# inputs/small155.in: cost 22370.46445079197
# inputs/medium229.in: cost 740.2965546041568
# inputs/medium17.in: cost 42351.65726700444
# inputs/medium46.in: cost 26349.537246920558
# inputs/medium81.in: cost 5693552071468.498
# inputs/medium72.in: cost 2012.4520503316007
# inputs/medium23.in: cost 2010.324698070716
# inputs/medium33.in: cost 180345.86682963584
# inputs/medium62.in: cost 145040.2889518945
# inputs/medium91.in: cost 165770.6986414011
# inputs/medium56.in: cost 35471.539122354945
# inputs/small145.in: cost 7085.700312135717
# inputs/medium239.in: cost 3316.3171748011923
# inputs/small18.in: cost 24471.870601390787
# inputs/large103.in: cost 1219.2493960703473
# inputs/small114.in: cost 391667.3688118974
# inputs/small49.in: cost 126531.14243574018
# inputs/large152.in: cost 5460.919064037762
# inputs/large230.in: cost 740.0096706164034
# inputs/small227.in: cost 150233.01581064696
# inputs/large29.in: cost 26436.22743904485
# inputs/large166.in: cost 11349151870.648458
# inputs/small120.in: cost 402517.3688118974
# inputs/large137.in: cost 9235.169924873979
# inputs/large78.in: cost 4823.678796990962
# inputs/small171.in: cost 36057222758713.37
# inputs/large255.in: cost 9912.008459487524
# inputs/small213.in: cost 168259.01581064696
# inputs/small182.in: cost 176947.41592657613
# inputs/large204.in: cost 17289.343392457646
# inputs/large195.in: cost 17236.618757457087
# inputs/small242.in: cost 139232.49323151432
# inputs/large224.in: cost 49343.003165842674
# inputs/small233.in: cost 7687.53919607959
# inputs/large58.in: cost 940.1533817374211
# inputs/large117.in: cost 9222.10370964767
# inputs/small151.in: cost 160979.41592657613
# inputs/large146.in: cost 5657.637877844622
# inputs/small100.in: cost 402517.3688118974
# inputs/small207.in: cost 5465.36969444755
# inputs/small196.in: cost 134746.49323151432
# inputs/large241.in: cost 9049.485127888202
# inputs/small256.in: cost 841194988802.5333
# inputs/medium6.in: cost 174341.09392684582
# inputs/large210.in: cost 2009.6900202267996
# inputs/large181.in: cost 2199.6883006495373
# inputs/medium248.in: cost 113665.77548060444
# inputs/small69.in: cost 654210808.7214726
# inputs/small134.in: cost 135055.01581064696
# inputs/large172.in: cost 3312.9426666402182
# inputs/small38.in: cost 131847.49323151432
# inputs/medium188.in: cost 6464.797760513179
# inputs/medium219.in: cost 116203.09314259021
# inputs/small165.in: cost 103025.01581064695
# inputs/large123.in: cost 16825.272917547205
# inputs/medium85.in: cost 74842.31591025766
# inputs/medium27.in: cost 90667.46887218827
# inputs/medium76.in: cost 20766.559978452075
# inputs/medium42.in: cost 469873.6126803392
# inputs/medium13.in: cost 366887.21945000824
# inputs/medium52.in: cost 80673.41592657614
# inputs/medium66.in: cost 327421.9519655701
# inputs/medium37.in: cost 32630.244495760428
# inputs/medium95.in: cost 122533.2735594355
# inputs/large133.in: cost 2009.7921335687965
# inputs/medium209.in: cost 66594.27786656591
# inputs/medium198.in: cost 121128.45091003989
# inputs/small28.in: cost 136828.14243574018
# inputs/small175.in: cost 96999.90918776828
# inputs/large162.in: cost 196743.49619676173
# inputs/small79.in: cost 104842.31591025766
# inputs/medium258.in: cost 51461.763964925536
# inputs/small124.in: cost 169368.41592657613
# inputs/large191.in: cost 409898622.9089065
# inputs/large200.in: cost 9003.068710104437
# inputs/small246.in: cost 654035849.0391412
# inputs/large251.in: cost 5732.91263799448
# inputs/small186.in: cost 7301.36969444755
# inputs/small217.in: cost 24578.155006612546
# inputs/small110.in: cost 402517.3688118974
# inputs/large19.in: cost 8.80128656781108e+21
# inputs/large156.in: cost 32884.079735018415
# inputs/small141.in: cost 7679.259650085521
# inputs/large107.in: cost 1.3877863688616068e+22
# inputs/large48.in: cost 1.8203415294845114e+21
# inputs/small223.in: cost 307586.01581064693
# inputs/large234.in: cost 28307.90454779565
# inputs/medium49.in: cost 90573.71848132418
# inputs/medium18.in: cost 19791.60223953209
# inputs/large53.in: cost 449.2277266951576
# inputs/medium226.in: cost 34607.601004301025
# inputs/small56.in: cost 4755.432763289833
# inputs/medium115.in: cost 4813.421013219795
# inputs/medium144.in: cost 85320.45102615177
# inputs/small238.in: cost 9821.115776315984
# inputs/medium243.in: cost 970894.4262866885
# inputs/small62.in: cost 140708.49323151432
# inputs/large179.in: cost 2009.7624110467814
# inputs/large36.in: cost 9004.864534558385
# inputs/medium183.in: cost 199343.8793492735
# inputs/small33.in: cost 402517.3688118974
# inputs/medium212.in: cost 33597.58213114773
# inputs/large67.in: cost 42471.82682360803
# inputs/large128.in: cost 2009.6900202267996
# inputs/medium170.in: cost 23952.214268270494
# inputs/large94.in: cost 29470.262246465125
# inputs/medium121.in: cost 3764836.799944384
# inputs/small91.in: cost 9936.560847848064
# inputs/small1.in: cost 170245.01581064696
# inputs/small81.in: cost 60615.64785724149
# inputs/medium131.in: cost 1090593.4333837244
# inputs/large84.in: cost 25469.479185190543
# inputs/medium160.in: cost 2012.9279182525959
# inputs/large138.in: cost 26445.128098705685
# inputs/large77.in: cost 8598.38197198718
# inputs/medium202.in: cost 247858.72822025963
# inputs/small23.in: cost 15004.999459326611
# inputs/medium193.in: cost 8066.713361327258
# inputs/large26.in: cost 31887.597250641327
# inputs/large169.in: cost 29367.155826280246
# inputs/small72.in: cost 12113.055979582477
# inputs/medium253.in: cost 79639.53595005497
# inputs/medium154.in: cost 49471.601004301025
# inputs/small228.in: cost 6674.259650085521
# inputs/medium105.in: cost 739.905609893065
# inputs/small46.in: cost 402223.3688118974
# inputs/large12.in: cost 16186.537277314139
# inputs/small17.in: cost 1976.0207180049056
# inputs/medium236.in: cost 5485.471604095874
# inputs/large43.in: cost 449.2277266951576
# inputs/medium59.in: cost 93747.97081429446
# inputs/large4.in: cost 58655.74072539819
# inputs/medium79.in: cost 3.2177043569582417e+25
# inputs/medium28.in: cost 78550.71848132418
# inputs/medium216.in: cost 208343.8793492735
# inputs/medium187.in: cost 93730.95043828132
# inputs/small37.in: cost 44458.48951581028
# inputs/large63.in: cost 9463.376878623501
# inputs/small66.in: cost 200346.01581064696
# inputs/medium247.in: cost 35314.04582634693
# inputs/large32.in: cost 488.6608560424044
# inputs/small259.in: cost 11114.055979582477
# inputs/medium125.in: cost 739.905609893065
# inputs/small95.in: cost 91166.28806142062
# inputs/medium9.in: cost 86689.77770728635
# inputs/small199.in: cost 139670.14243574018
# inputs/small208.in: cost 16252.773800853292
# inputs/medium174.in: cost 82929.58213114773
# inputs/large90.in: cost 5461.06277515878
# inputs/large149.in: cost 318243.1576927038
# inputs/small52.in: cost 96026.49323151434
# inputs/large57.in: cost 3317.6209870759767
# inputs/large118.in: cost 972318431300914.8
# inputs/medium222.in: cost 327421.9519655701
# inputs/medium140.in: cost 114369.2735594355
# inputs/medium111.in: cost 145895.6706898088
# inputs/medium101.in: cost 90896.58026927942
# inputs/medium150.in: cost 97109.01581064695
# inputs/medium232.in: cost 3044.4055032898655
# inputs/small13.in: cost 338817.3688118974
# inputs/large108.in: cost 449.2277266951576
# inputs/large47.in: cost 25470.570471544594
# inputs/small42.in: cost 125521.49323151434
# inputs/large16.in: cost 5059497.514818476
# inputs/large159.in: cost 26188.852013835323
# inputs/large80.in: cost 9310.95417466403
# inputs/small218.in: cost 739.905609893065
# inputs/small189.in: cost 16258.303969737704
# inputs/medium164.in: cost 118384.71848132418
# inputs/small5.in: cost 33575.87060139079
# inputs/small249.in: cost 5467.057014727672
# inputs/small85.in: cost 33175.06083808615
# inputs/medium135.in: cost 73560.97081429446
# inputs/large22.in: cost 2014.4916102931154
# inputs/medium257.in: cost 134388.77468467777
# inputs/small76.in: cost 131443.49323151432
# inputs/large73.in: cost 14843.287174688727
# inputs/small27.in: cost 173636.01581064696
# inputs/medium197.in: cost 69834.33718167272
# inputs/medium206.in: cost 9004.256101689989
# inputs/medium38.in: cost 31167.016830263576
# inputs/medium69.in: cost 739.905609893065
# inputs/large5.in: cost 10003.967773246028
# inputs/medium78.in: cost 21244.285934618558
# inputs/medium29.in: cost 151755.77468467777
# inputs/small36.in: cost 368917.3688118974
# inputs/medium186.in: cost 29220.644302788496
# inputs/medium217.in: cost 86737.60100430102
# inputs/large62.in: cost 25138.611390392995
# inputs/medium246.in: cost 9003.104074763272
# inputs/small67.in: cost 203540.01581064696
# inputs/large33.in: cost 42344.508942597466
# inputs/medium8.in: cost 83000.01581064695
# inputs/small94.in: cost 29471.14243574018
# inputs/medium124.in: cost 110314.01581064695
# inputs/small258.in: cost 841194988802.5333
# inputs/medium175.in: cost 40441.7496810386
# inputs/small209.in: cost 25768.72554941205
# inputs/small198.in: cost 402517.3688118974
# inputs/large91.in: cost 2696907.097666732
# inputs/large148.in: cost 53911385692858.586
# inputs/small53.in: cost 114471.14243574018
# inputs/large119.in: cost 1990079249672151.2
# inputs/large56.in: cost 25285.01117324041
# inputs/medium223.in: cost 440142.01100257214
# inputs/medium141.in: cost 2132.8400215931965
# inputs/medium110.in: cost 129956.15641845592
# inputs/medium100.in: cost 1536.5219859395659
# inputs/medium151.in: cost 54186.72865993183
# inputs/small12.in: cost 7690.596708444446
# inputs/medium233.in: cost 98913.74968103861
# inputs/large46.in: cost 449.2277266951576
# inputs/large109.in: cost 14981.413544937715
# inputs/small43.in: cost 402517.3688118974
# inputs/large158.in: cost 51484.06662321693
# inputs/large17.in: cost 25150.87307671882
# inputs/large81.in: cost 56795.6399694227
# inputs/medium165.in: cost 83006.95043828132
# inputs/small188.in: cost 389687.3688118974
# inputs/small219.in: cost 170177.41592657613
# inputs/small4.in: cost 134544.90918776827
# inputs/medium134.in: cost 6819599.358993003
# inputs/small84.in: cost 4306.200386104066
# inputs/small248.in: cost 162313.01581064696
# inputs/large23.in: cost 739.905609893065
# inputs/small77.in: cost 3594720093.337257
# inputs/medium256.in: cost 2009.5536923187667
# inputs/large72.in: cost 2009.81943001999
# inputs/medium207.in: cost 3313.702452867157
# inputs/medium196.in: cost 86608.81407646283
# inputs/small26.in: cost 133704.01581064696
# inputs/medium39.in: cost 3313.702452867157
# inputs/medium68.in: cost 22004.155042308324
# inputs/medium48.in: cost 1145189642760.922
# inputs/large1.in: cost 16300.186210609076
# inputs/medium19.in: cost 1208332.5006644411
# inputs/large52.in: cost 16515.496263738427
# inputs/medium227.in: cost 739.905609893065
# inputs/small57.in: cost 13075.283972521378
# inputs/medium114.in: cost 4.6931992338409397e+20
# inputs/small239.in: cost 4559.5478183665045
# inputs/medium145.in: cost 3666579106.7676134
# inputs/small63.in: cost 10156.414050058094
# inputs/medium242.in: cost 113815.45091003989
# inputs/large37.in: cost 9002.945204975815
# inputs/large178.in: cost 11036.995602909514
# inputs/medium213.in: cost 59784.31591025766
# inputs/small32.in: cost 92471.14243574018
# inputs/medium182.in: cost 103697.21945000821
# inputs/large129.in: cost 15326.466184056517
# inputs/large66.in: cost 3.111948248571127e+22
# inputs/medium171.in: cost 262303027.28067553
# inputs/large95.in: cost 17741.2153530905
# inputs/small90.in: cost 402517.3688118974
# inputs/medium120.in: cost 2906494.8546234965
# inputs/medium130.in: cost 2.3104830403269864e+16
# inputs/small80.in: cost 82087.90918776828
# inputs/large85.in: cost 739.905609893065
# inputs/medium161.in: cost 18434.58829806748
# inputs/large76.in: cost 2009.6378778446226
# inputs/large139.in: cost 1219.6584641704749
# inputs/medium192.in: cost 169077.41592657613
# inputs/small22.in: cost 13175.870203281267
# inputs/medium203.in: cost 100336.60100430102
# inputs/large168.in: cost 9003.344539167265
# inputs/large27.in: cost 24818.055532457198
# inputs/medium252.in: cost 42575.408664267816
# inputs/small73.in: cost 46032.55792167091
# inputs/small229.in: cost 5316.653924857668
# inputs/medium155.in: cost 79353.01581064695
# inputs/medium104.in: cost 771.905609893065
# inputs/small47.in: cost 25493.746671151974
# inputs/large13.in: cost 1219.4683461511656
# inputs/medium237.in: cost 81487.2735594355
# inputs/small16.in: cost 402517.3688118974
# inputs/large42.in: cost 24850.479185190543
# inputs/medium58.in: cost 740.6766156450144
# inputs/large6.in: cost 34312.67409389911
# inputs/medium88.in: cost 115207.5704478249
# inputs/medium176.in: cost 5461.749730503738
# inputs/large92.in: cost 25031.996227876345
# inputs/medium127.in: cost 40837.7496810386
# inputs/small97.in: cost 23014.055979582477
# inputs/small139.in: cost 57949.49323151434
# inputs/small64.in: cost 22102.55792167091
# inputs/medium245.in: cost 97342.31591025766
# inputs/large30.in: cost 8.80128656781108e+21
# inputs/small168.in: cost 132970.49323151432
# inputs/medium214.in: cost 31243.559978452075
# inputs/medium185.in: cost 3844869163929190.5
# inputs/small35.in: cost 60360.040103022824
# inputs/large61.in: cost 121260643526.13875
# inputs/large229.in: cost 449.2277266951576
# inputs/medium113.in: cost 5828639920.362298
# inputs/medium142.in: cost 29749666139.699474
# inputs/large55.in: cost 9003.090162175587
# inputs/medium220.in: cost 42249.644302788496
# inputs/small50.in: cost 121671.14243574018
# inputs/small40.in: cost 1.1305039340295386e+17
# inputs/large14.in: cost 5461.319061079829
# inputs/medium230.in: cost 9013.269313367924
# inputs/small11.in: cost 4313.853839147427
# inputs/large45.in: cost 32884.079735018415
# inputs/medium152.in: cost 5462.654135365088
# inputs/medium103.in: cost 1219.2493960703473
# inputs/large239.in: cost 1219.4683461511656
# inputs/large71.in: cost 1.7821335526226867e+18
# inputs/small178.in: cost 9295.414050058094
# inputs/small25.in: cost 23061.414050058094
# inputs/medium195.in: cost 133968.12341746793
# inputs/medium204.in: cost 118892804.02159756
# inputs/large20.in: cost 76748.67290567295
# inputs/small129.in: cost 127642.87987602052
# inputs/medium255.in: cost 59306.570447824895
# inputs/small74.in: cost 148782.01581064696
# inputs/small7.in: cost 267765.01581064693
# inputs/small87.in: cost 11001.41896328293
# inputs/medium137.in: cost 80706.31664124977
# inputs/large82.in: cost 17615.550904765045
# inputs/medium166.in: cost 9.769131275556062e+26
# inputs/medium98.in: cost 5461.205948025516
# inputs/large2.in: cost 41217.783624430755
# inputs/medium146.in: cost 7512.944637029858
# inputs/medium117.in: cost 126655.17477858535
# inputs/small54.in: cost 58145.55792167091
# inputs/small109.in: cost 308509.01581064693
# inputs/large51.in: cost 1219.4364378135592
# inputs/medium224.in: cost 1814038.1865564077
# inputs/small158.in: cost 25471.14243574018
# inputs/medium123.in: cost 2081.9446370298583
# inputs/small93.in: cost 76578.90918776828
# inputs/large219.in: cost 28540.010276797566
# inputs/large188.in: cost 9397.570040302298
# inputs/medium172.in: cost 7519.713361327258
# inputs/large96.in: cost 16871.82762725585
# inputs/large248.in: cost 25959.60995317753
# inputs/medium181.in: cost 10048.181934489492
# inputs/small31.in: cost 6205.96354384873
# inputs/medium210.in: cost 3313.702452867157
# inputs/large65.in: cost 2689.7624110467814
# inputs/medium241.in: cost 142266.4493802802
# inputs/small60.in: cost 402517.3688118974
# inputs/large34.in: cost 40344.79808124315
# inputs/large24.in: cost 2012.9489138158945
# inputs/small70.in: cost 6010.797760513179
# inputs/medium251.in: cost 24710.214268270494
# inputs/large75.in: cost 3.804151090933358e+22
# inputs/medium200.in: cost 6.44026957088509e+16
# inputs/small21.in: cost 4945.125063845673
# inputs/medium191.in: cost 715702.6901040927
# inputs/large258.in: cost 5579.351038754716
# inputs/large86.in: cost 16740.482545254326
# inputs/medium162.in: cost 8466.09436607406
# inputs/small3.in: cost 384517.3688118974
# inputs/large198.in: cost 25231.448006877636
# inputs/large209.in: cost 449.2277266951576
# inputs/small83.in: cost 6010.797760513179
# inputs/medium133.in: cost 4360.049356170322
# inputs/small15.in: cost 4479.129694740593
# inputs/medium234.in: cost 152441.71848132418
# inputs/small148.in: cost 6299142170004439.0
# inputs/large41.in: cost 449.2277266951576
# inputs/small44.in: cost 142889.01581064696
# inputs/small119.in: cost 402517.3688118974
# inputs/large10.in: cost 25348.850415753295
# inputs/medium107.in: cost 8157666103091330.0
# inputs/medium156.in: cost 227403.01866654333
# inputs/large3.in: cost 44842.53486033848
# inputs/medium147.in: cost 1102075.3832156088
# inputs/medium116.in: cost 5488.288205061868
# inputs/small108.in: cost 79418.68109196615
# inputs/small55.in: cost 99080.97388281235
# inputs/large50.in: cost 5461.50348891716
# inputs/small159.in: cost 4.237538927983462e+17
# inputs/medium225.in: cost 2010.4884195080806
# inputs/small92.in: cost 275009.01581064693
# inputs/medium122.in: cost 15804734.0485046
# inputs/large189.in: cost 2009.914104605332
# inputs/large218.in: cost 449.2277266951576
# inputs/medium173.in: cost 8976.447846966536
# inputs/large249.in: cost 489.2277266951576
# inputs/large97.in: cost 8461.06277515878
# inputs/medium211.in: cost 27037.28863512895
# inputs/small30.in: cost 152625.49323151432
# inputs/medium180.in: cost 9003.804595073125
# inputs/large64.in: cost 26112.47514804741
# inputs/small61.in: cost 79383.19528185045
# inputs/medium240.in: cost 2967945460076.282
# inputs/large35.in: cost 14842.31591025766
# inputs/large25.in: cost 2010.069719078095
# inputs/medium250.in: cost 64800.32008447361
# inputs/small71.in: cost 275397.01581064693
# inputs/large74.in: cost 10618.633464702434
# inputs/medium190.in: cost 149775.77770728635
# inputs/small20.in: cost 68533.87060139078
# inputs/medium201.in: cost 89275.86682963585
# inputs/large87.in: cost 40344.76910670781
# inputs/large259.in: cost 14842.74484805036
# inputs/medium163.in: cost 1019024.1991597048
# inputs/large208.in: cost 2009.6900202267996
# inputs/large199.in: cost 5462.532741486513
# inputs/small2.in: cost 160054.49323151432
# inputs/medium132.in: cost 68284735104.48154
# inputs/small82.in: cost 167299.14243574018
# inputs/small149.in: cost 2.983750939284194e+20
# inputs/medium235.in: cost 54861.01500498319
# inputs/small14.in: cost 1.968854419095276e+19
# inputs/large40.in: cost 2631233578.9860263
# inputs/small118.in: cost 166924.01581064696
# inputs/small45.in: cost 224346.01581064696
# inputs/large11.in: cost 26247.537709175405
# inputs/medium106.in: cost 3362.047565272437
# inputs/medium157.in: cost 34867.155042308324
# inputs/large7.in: cost 25351.981195707154
# inputs/medium89.in: cost 5741.101332588853
# inputs/medium177.in: cost 19401.700610414515
# inputs/large93.in: cost 9318.344539167265
# inputs/small96.in: cost 5846325.8098067725
# inputs/medium126.in: cost 3314.4478469665355
# inputs/medium244.in: cost 3848.2175655993733
# inputs/small65.in: cost 29482.61668325922
# inputs/small138.in: cost 56878.61668325922
# inputs/large31.in: cost 3312.712004651994
# inputs/small34.in: cost 179228.01581064696
# inputs/medium184.in: cost 65299736398.06615
# inputs/medium215.in: cost 19742.648009656725
# inputs/small169.in: cost 134934.14243574018
# inputs/large60.in: cost 32884.079735018415
# inputs/large228.in: cost 6640.75941021091
# inputs/medium112.in: cost 81161.60100430102
# inputs/medium143.in: cost 3314.7457647132846
# inputs/large54.in: cost 9003.169924873979
# inputs/medium221.in: cost 69182.26277020667
# inputs/small51.in: cost 7224.478381807051
# inputs/medium260.in: cost 9004.256101689989
# inputs/small41.in: cost 224346.01581064696
# inputs/large15.in: cost 2009.729150573242
# inputs/small10.in: cost 121557.90918776828
# inputs/medium231.in: cost 15706.240636582126
# inputs/large44.in: cost 1219.3534567936856
# inputs/medium153.in: cost 9533.552262102847
# inputs/medium102.in: cost 72198.58026927942
# inputs/large238.in: cost 2009.729150573242
# inputs/large70.in: cost 449.2277266951576
# inputs/medium205.in: cost 67983.74968103861
# inputs/medium194.in: cost 6362.506101865805
# inputs/small24.in: cost 167925.01581064696
# inputs/small179.in: cost 359317.3688118974
# inputs/large21.in: cost 1219.4364378135592
# inputs/small75.in: cost 402517.3688118974
# inputs/medium254.in: cost 9006.249707354804
# inputs/small128.in: cost 167101.01581064696
# inputs/small6.in: cost 5.390940282074045e+17
# inputs/medium136.in: cost 3860.0032806546633
# inputs/small86.in: cost 6.15812482158328e+18
# inputs/large83.in: cost 449.2277266951576
# inputs/medium167.in: cost 94241.91519133469
# inputs/medium99.in: cost 2009.5536923187667
# inputs/small133.in: cost 9407.414050058094
# inputs/large175.in: cost 81663.31479935496
# inputs/small162.in: cost 4316.653924857668
# inputs/large124.in: cost 25539.31100903896
# inputs/small200.in: cost 140042.49323151432
# inputs/small191.in: cost 77342.31591025766
# inputs/large246.in: cost 5461.06277515878
# inputs/large98.in: cost 9102.090762736752
# inputs/medium1.in: cost 104986.86682963585
# inputs/small251.in: cost 28368.77380085329
# inputs/large217.in: cost 24757.35236792304
# inputs/large186.in: cost 5665.471619664124
# inputs/large110.in: cost 739.905609893065
# inputs/small156.in: cost 351747.77548060444
# inputs/large141.in: cost 32884.079735018415
# inputs/small107.in: cost 1.78978398535434e+18
# inputs/large223.in: cost 1.406708476180449e+23
# inputs/medium119.in: cost 6.2950154396194404e+25
# inputs/medium148.in: cost 255593.8793492735
# inputs/small234.in: cost 391621.4582272279
# inputs/medium45.in: cost 280343.8793492735
# inputs/medium14.in: cost 9083.407041257833
# inputs/medium20.in: cost 70287.2735594355
# inputs/medium71.in: cost 7.628558978559199e+17
# inputs/medium82.in: cost 92635.31664124977
# inputs/medium92.in: cost 124259.8939180025
# inputs/medium61.in: cost 261834.8027361758
# inputs/medium30.in: cost 3779198889109.19
# inputs/medium55.in: cost 36448.644302788496
# inputs/medium158.in: cost 14015.153865252283
# inputs/small224.in: cost 14596084.65028731
# inputs/medium109.in: cost 5748.506101865805
# inputs/large233.in: cost 18026.127074191903
# inputs/small117.in: cost 31327043656.740604
# inputs/large151.in: cost 40366.75334393522
# inputs/small146.in: cost 26302.14243574018
# inputs/large100.in: cost 2010.3747986432481
# inputs/large196.in: cost 16670.739955530258
# inputs/large207.in: cost 3417.9615740509826
# inputs/small241.in: cost 35416.230933665494
# inputs/large88.in: cost 89049.92009541018
# inputs/large256.in: cost 14842.31591025766
# inputs/small181.in: cost 9841849799753.463
# inputs/small210.in: cost 7431.36969444755
# inputs/large134.in: cost 30794536641.894592
# inputs/small172.in: cost 18837.41896328293
# inputs/large165.in: cost 16323.940391914924
# inputs/small123.in: cost 855893.1366523188
# inputs/large145.in: cost 1755.8574882759133
# inputs/small103.in: cost 10488.672654521284
# inputs/large114.in: cost 434289.4587443231
# inputs/small152.in: cost 7141.303969737704
# inputs/small230.in: cost 59421.31591025766
# inputs/large227.in: cost 2009.81943001999
# inputs/small166.in: cost 1506595654424483.0
# inputs/large120.in: cost 739.905609893065
# inputs/small137.in: cost 102369.01581064695
# inputs/large171.in: cost 449.2277266951576
# inputs/small255.in: cost 44203.90918776828
# inputs/medium5.in: cost 20534.092604027108
# inputs/medium129.in: cost 53247.76989534357
# inputs/small99.in: cost 6313.853839147427
# inputs/large182.in: cost 41146.57309224658
# inputs/large213.in: cost 11770.67080191242
# inputs/small195.in: cost 591273.09638437
# inputs/small204.in: cost 163413.01581064696
# inputs/medium178.in: cost 7775.189229248253
# inputs/large242.in: cost 26427.66355979127
# inputs/medium75.in: cost 1282200355383327.0
# inputs/medium24.in: cost 1685.5184730686985
# inputs/medium86.in: cost 2.6452065394921474e+25
# inputs/large8.in: cost 25043.22743904485
# inputs/medium10.in: cost 93837.62251857058
# inputs/medium41.in: cost 1219.2493960703473
# inputs/medium51.in: cost 5461.906468335367
# inputs/medium96.in: cost 7064409.051051446
# inputs/medium34.in: cost 116847.01581064695
# inputs/medium65.in: cost 5462.802483676758
# inputs/large252.in: cost 14913.371110224503
# inputs/small214.in: cost 21432.180718494474
# inputs/small185.in: cost 590417.244074753
# inputs/medium168.in: cost 28625.262770206664
# inputs/small9.in: cost 165034.49323151432
# inputs/large203.in: cost 5059497.514818476
# inputs/large192.in: cost 45594.68738783222
# inputs/small245.in: cost 8188.700312135717
# inputs/small89.in: cost 102487.49323151434
# inputs/medium139.in: cost 9132.957198246593
# inputs/large161.in: cost 5791.405947186993
# inputs/small127.in: cost 57826.18059827322
# inputs/large130.in: cost 4.603542439207806e+20
# inputs/small176.in: cost 4316.653924857668
# inputs/large237.in: cost 17474.081849483835
# inputs/small220.in: cost 46557.7863675251
# inputs/small142.in: cost 531734.8944904564
# inputs/large104.in: cost 27105.156720410574
# inputs/small113.in: cost 9656.666394513277
# inputs/large155.in: cost 26083.055532457198
# inputs/large144.in: cost 26863.156720410574
# inputs/small102.in: cost 136866.41592657613
# inputs/large115.in: cost 739.905609893065
# inputs/small153.in: cost 402517.3688118974
# inputs/small231.in: cost 177680.0943121089
# inputs/large226.in: cost 31873.33947904865
# inputs/small260.in: cost 274540.01581064693
# inputs/small167.in: cost 32227.288061420615
# inputs/large121.in: cost 113842.31591025766
# inputs/small136.in: cost 9609.669596898848
# inputs/large170.in: cost 2009.7624110467814
# inputs/small98.in: cost 2.2969830667162673e+19
# inputs/medium128.in: cost 1010669949.0704663
# inputs/medium4.in: cost 129319.86682963585
# inputs/small254.in: cost 6368.36969444755
# inputs/large212.in: cost 9003.27769992126
# inputs/large183.in: cost 14842.31591025766
# inputs/medium179.in: cost 160619.10813726918
# inputs/small205.in: cost 135325.49323151432
# inputs/small194.in: cost 20951.96354384873
# inputs/large243.in: cost 2009.844933433341
# inputs/medium74.in: cost 58268.89777949566
# inputs/medium25.in: cost 9007.807663591017
# inputs/medium87.in: cost 9131.267821185307
# inputs/medium11.in: cost 105846.31664124977
# inputs/large9.in: cost 25049.80838231716
# inputs/medium40.in: cost 28695801.129746456
# inputs/medium50.in: cost 3219.640340781439
# inputs/medium97.in: cost 14843.858881895467
# inputs/medium35.in: cost 14842.31591025766
# inputs/medium64.in: cost 29473.493231514334
# inputs/large253.in: cost 52001.52521027387
# inputs/medium169.in: cost 94543.01581064695
# inputs/small184.in: cost 164213.01581064696
# inputs/small215.in: cost 7726644.847997707
# inputs/large193.in: cost 9234.455460126223
# inputs/large202.in: cost 16866.502952000872
# inputs/small8.in: cost 111268.90918776828
# inputs/medium138.in: cost 55847.601004301025
# inputs/small88.in: cost 37911.61668325922
# inputs/small244.in: cost 5968.303969737704
# inputs/large160.in: cost 15842.683499505722
# inputs/small126.in: cost 8243.53919607959
# inputs/large131.in: cost 103144.47849875948
# inputs/small177.in: cost 13064.469184168061
# inputs/large236.in: cost 3556.024494917826
# inputs/small221.in: cost 140930.49323151432
# inputs/small143.in: cost 9440.055979582477
# inputs/large105.in: cost 2009.6378778446226
# inputs/small112.in: cost 102024.90918776828
# inputs/large154.in: cost 49470.42559341177
# inputs/small132.in: cost 164028.01581064696
# inputs/large174.in: cost 17345.65927250108
# inputs/small163.in: cost 136406.97388281234
# inputs/large125.in: cost 449.2277266951576
# inputs/small190.in: cost 227346.01581064696
# inputs/small201.in: cost 105066.49323151434
# inputs/large99.in: cost 449.2277266951576
# inputs/large247.in: cost 9007.913256375208
# inputs/small250.in: cost 166484.01581064696
# inputs/large187.in: cost 25409.981195707154
# inputs/large216.in: cost 739.905609893065
# inputs/large111.in: cost 30433.920095410187
# inputs/small157.in: cost 104946.2309336655
# inputs/large140.in: cost 25211.338609474133
# inputs/small106.in: cost 6679.303969737704
# inputs/large222.in: cost 2.2985545744906705e+20
# inputs/medium118.in: cost 1196453.595666348
# inputs/small235.in: cost 38405.48951581028
# inputs/medium149.in: cost 1.584123183889258e+18
# inputs/medium44.in: cost 21121.905433172422
# inputs/medium15.in: cost 3314.4478469665355
# inputs/medium21.in: cost 2010.64515733971
# inputs/medium70.in: cost 6009.5536923187665
# inputs/medium83.in: cost 739.905609893065
# inputs/medium93.in: cost 31048.75320223392
# inputs/medium60.in: cost 177517.6706898088
# inputs/medium31.in: cost 10487.150422028439
# inputs/medium54.in: cost 23545.849591425616
# inputs/small225.in: cost 9679.53919607959
# inputs/medium159.in: cost 617309.1736192836
# inputs/medium108.in: cost 110674.12136068677
# inputs/large232.in: cost 5461.714446147264
# inputs/small116.in: cost 10014.055979582477
# inputs/large150.in: cost 25877.269379353802
# inputs/small147.in: cost 76550.90918776828
# inputs/large101.in: cost 16745.413544937717
# inputs/large206.in: cost 3312.712004651994
# inputs/large197.in: cost 44850.91972498412
# inputs/small240.in: cost 165703.01581064696
# inputs/large257.in: cost 28278.920095410187
# inputs/large89.in: cost 9783.236812035973
# inputs/small211.in: cost 32860.99249281182
# inputs/small180.in: cost 5463.870203281269
# inputs/large135.in: cost 25548.11699122282
# inputs/small173.in: cost 5465.36969444755
# inputs/large164.in: cost 18791.066582757958
# inputs/small122.in: cost 68842.31591025766
